# %% [markdown]
# # Pandas Vs Numpy
# 1. Pandas has a numpy core
# 2. Extra structures and tools ,but sometimes u=have to strip it away

# %%
import numpy as np
import pandas as pd

df= pd.read_csv("heart.csv")

# %%
data =df.to_numpy()
data = df.values
data
# Out:
# array([[63.,  1.,  3., ...,  0.,  1.,  1.],
#        [37.,  1.,  2., ...,  0.,  2.,  1.],
#        [41.,  0.,  1., ...,  0.,  2.,  1.],
#        ...,
#        [68.,  1.,  0., ...,  2.,  3.,  0.],
#        [57.,  1.,  0., ...,  1.,  3.,  0.],
#        [57.,  0.,  1., ...,  1.,  2.,  0.]])

# %% [markdown]
# # Why to never use  .values:-
#  https://bit.ly/2RrecCR or https://pandas-docs.github.io/pandas-docs-travis/whatsnew/v0.24.0.html#accessing-the-values-in-a-series-or-index

# %%
df.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   3       145   233    1        0      150      0      2.3      0
# 1   37    1   2       130   250    0        1      187      0      3.5      0
# 2   41    0   1       130   204    0        0      172      0      1.4      2
# 3   56    1   1       120   236    0        1      178      0      0.8      2
# 4   57    0   0       120   354    0        1      163      1      0.6      2
#
#    ca  thal  target
# 0   0     1       1
# 1   0     2       1
# 2   0     2       1
# 3   0     2       1
# 4   0     2       1

# %%
print (data.dtype, data)
# Out:
# float64 [[63.  1.  3. ...  0.  1.  1.]
#  [37.  1.  2. ...  0.  2.  1.]
#  [41.  0.  1. ...  0.  2.  1.]
#  ...
#  [68.  1.  0. ...  2.  3.  0.]
#  [57.  1.  0. ...  1.  3.  0.]
#  [57.  0.  1. ...  1.  2.  0.]]

# %%
data[0,0]=100
df.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   3       145   233    1        0      150      0      2.3      0
# 1   37    1   2       130   250    0        1      187      0      3.5      0
# 2   41    0   1       130   204    0        0      172      0      1.4      2
# 3   56    1   1       120   236    0        1      178      0      0.8      2
# 4   57    0   0       120   354    0        1      163      1      0.6      2
#
#    ca  thal  target
# 0   0     1       1
# 1   0     2       1
# 2   0     2       1
# 3   0     2       1
# 4   0     2       1

# %%
df2=df[["age","sex","cp"]]
data2=df2.to_numpy() # to keep original data use -> .copy()
data2[0,0]=100
df2
# Out:
#      age  sex  cp
# 0    100    1   3
# 1     37    1   2
# 2     41    0   1
# 3     56    1   1
# 4     57    0   0
# ..   ...  ...  ..
# 298   57    0   0
# 299   45    1   3
# 300   68    1   0
# 301   57    1   0
# 302   57    0   1
#
# [303 rows x 3 columns]

# %%
print (
    df['age'].mean(),
    df['age'].to_numpy().mean(),
       )
# Out:
# 54.366336633663366 54.366336633663366

# %%
print (
    df['age'].quantile(0.5),
    #df['age'].to_numpy().quantile(0.5),
       )
# Out:
# 55.0

# %%
print (
    #df['age'].reshape((3,-1)),
    df['age'].to_numpy().reshape((3,-1)),
      )
# Out:
# [[63 37 41 56 57 57 56 44 52 57 54 48 49 64 58 50 58 66 43 69 59 44 42 61
#   40 71 59 51 65 53 41 65 44 54 51 46 54 54 65 65 51 48 45 53 39 52 44 47
#   53 53 51 66 62 44 63 52 48 45 34 57 71 54 52 41 58 35 51 45 44 62 54 51
#   29 51 43 55 51 59 52 58 41 45 60 52 42 67 68 46 54 58 48 57 52 54 45 53
#   62 52 43 53 42]
#  [59 63 42 50 68 69 45 50 50 64 57 64 43 55 37 41 56 46 46 64 59 41 54 39
#   34 47 67 52 74 54 49 42 41 41 49 60 62 57 64 51 43 42 67 76 70 44 60 44
#   42 66 71 64 66 39 58 47 35 58 56 56 55 41 38 38 67 67 62 63 53 56 48 58
#   58 60 40 60 64 43 57 55 65 61 58 50 44 60 54 50 41 51 58 54 60 60 59 46
#   67 62 65 44 60]
#  [58 68 62 52 59 60 49 59 57 61 39 61 56 43 62 63 65 48 63 55 65 56 54 70
#   62 35 59 64 47 57 55 64 70 51 58 60 77 35 70 59 64 57 56 48 56 66 54 69
#   51 43 62 67 59 45 58 50 62 38 66 52 53 63 54 66 55 49 54 56 46 61 67 58
#   47 52 58 57 58 61 42 52 59 40 61 46 59 57 57 55 61 58 58 67 44 63 63 59
#   57 45 68 57 57]]
